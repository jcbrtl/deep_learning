# %%
import sys
sys.path.append('../src')

from pytorch_lightning import Trainer
from model_gnn import GNN_Module
from min_max_graph_data import MinMaxGraphModule

# %%
data = MinMaxGraphModule()
model = GNN_Module()
trainer = Trainer(check_val_every_n_epoch=5, gpus=1, max_epochs=150)
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]

# %%
trainer.fit(model, datamodule=data)
# Out:
#   | Name         | Type             | Params
# --------------------------------------------------
# 0 | model        | GNN_Model        | 951 K
# 1 | loss         | CrossEntropyLoss | 0
# 2 | val_accuracy | Accuracy         | 0
# Validation sanity check: 0it [00:00, ?it/s]
# /home/kushaj/miniconda3/envs/dl/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:45: UserWarning: The dataloader, val dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   warnings.warn(*args, **kwargs)
# Epoch 0:   0%|          | 2/400 [00:00<00:34, 11.50it/s, loss=358.165, v_num=15]
# ...

# %% [markdown]
# The best model achieved 98% accuracy. This is without hyperparameter optimization but we can still observe from this that GNN can solve this problem. The fluctutations in validation accuracy are probably due to similiar distribution of validation data i.e. the random sampling of data might have sampled data in the same region.
